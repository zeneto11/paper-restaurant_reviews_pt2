# %% [markdown]
# Classificação de Texto Multilabel

# %% [markdown]
# José Augusto de Almeida Neto

# %% [markdown]
# ## Importar bibliotecas

# %%
import os
import time
import pandas as pd
import torch
from dotenv import load_dotenv
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
from transformers import BertForSequenceClassification, BertTokenizer

# %% [markdown]
# ## Carregar datasets

# %%
# Carregar dataset
df_case_study = pd.read_csv('../datasets/dataset-case_study-tratado.csv')
df_case_study
# Out:
#      restaurante_name                    user_name  \
# 0            cipriani             Viva Gastronomia
# 1            cipriani              Аннa Шкаленкова
# 2            cipriani             Roberto Barretto
# 3            cipriani       GRUPO VANDERSON SOARES
# 4            cipriani               Maria Baptista
# ...               ...                          ...
# 4968          tangara            Christopher Lopez
# 4969          tangara                Silvio Marcos
# 4970          tangara                   Maria Lins
# 4971          tangara        Ricardo Polisel Alves
# 4972          tangara  Alex Montero INMOTION Video
#
#                      review_date  stars  \
# 0         9 anos atrás no Zomato      1
# 1        11 dias atrás no Google      1
# 2         um mês atrás no Google      1
# 3         um mês atrás no Google      1
# 4         um mês atrás no Google      1
# ...                          ...    ...
# 4968      4 anos atrás no Google      1
# 4969      4 anos atrás no Google      1
# 4970      4 anos atrás no Google      1
# 4971  5 anos atrás no Foursquare      0
# 4972  5 anos atrás no Foursquare      0
#
#                                            comment_text     year    platform  \
# 0     Hotelaria e gastronomia são duas  artes demand...     2015      Zomato
# 1     It was  possible to order only a tasting menu;...     2024      Google
# 2     Grade 10!   Food:  5    Service:  4    Atmosph...  Unknown      Google
# 3     Wonderful    Food:  5    Service:  5    Atmosp...  Unknown      Google
# 4     We had  a great dining experience at Cipriani....  Unknown      Google
# ...                                                 ...      ...         ...
# 4968  Great place for lunch. Nice scenary good wine ...     2020      Google
# 4969                         Boa comida. Sabor marcante     2020      Google
# 4970                                      Comida divina     2020      Google
# 4971  Tasting Menu was indeed very  good. Service wa...     2019  Foursquare
# 4972                          M A R A V I L H O S O !!!     2019  Foursquare
#
#      language                            comment_text_translated
# 0          pt  Hotelaria e gastronomia são duas artes demanda...
# 1          en  Foi possível encomendar apenas um menu de degu...
# 2          en                                          Grade 10!
# 3          en                              comida maravilhosa: 5
# 4          en  Tivemos uma ótima experiência gastronômica em ...
# ...       ...                                                ...
# 4968       en  Ótimo lugar para o almoço.Lista de vinhos de b...
# 4969       pt                         Boa comida. Sabor marcante
# 4970       it                                      comida divina
# 4971       en  O menu de degustação foi realmente muito bom.O...
# 4972       pt                          M A R A V I L H O S O !!!
#
# [4973 rows x 9 columns]

# %%
labels = ['ambiente', 'bebida', 'comida', 'geral',
          'localização', 'outros', 'preço', 'serviço']

# %%
# Renomeando a coluna de df
df = df_case_study[['comment_text_translated']].copy()
df.rename(columns={'comment_text_translated': 'sentenca'}, inplace=True)
df
# Out:
#                                                sentenca
# 0     Hotelaria e gastronomia são duas artes demanda...
# 1     Foi possível encomendar apenas um menu de degu...
# 2                                             Grade 10!
# 3                                 comida maravilhosa: 5
# 4     Tivemos uma ótima experiência gastronômica em ...
# ...                                                 ...
# 4968  Ótimo lugar para o almoço.Lista de vinhos de b...
# 4969                         Boa comida. Sabor marcante
# 4970                                      comida divina
# 4971  O menu de degustação foi realmente muito bom.O...
# 4972                          M A R A V I L H O S O !!!
#
# [4973 rows x 1 columns]

# %% [markdown]
# ## Hiperparâmetros

# %%
# Hiperparâmetros
max_len = 128
test_batch_size = 4
num_labels = len(labels)
threshold = 0.28

# %% [markdown]
# ## Funções auxiliares

# %%
class TokenizeDataset(torch.utils.data.Dataset):

    def __init__(self, df, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.df = df
        self.title = df['sentenca']
        self.max_len = max_len

    def __len__(self):
        return len(self.title)

    def __getitem__(self, index):
        title = str(self.title[index])
        title = " ".join(title.split())

        inputs = self.tokenizer.encode_plus(
            title,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            return_token_type_ids=True,
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )

        return {
            'input_ids': inputs['input_ids'].flatten(),
            'attention_mask': inputs['attention_mask'].flatten(),
            'token_type_ids': inputs["token_type_ids"].flatten()
        }

# %%
def run_prediction(model, df_test):
    start_time = time.time()

    # Carregar o tokenizador BERT
    tokenizer = BertTokenizer.from_pretrained(
        'neuralmind/bert-base-portuguese-cased')

    # Tokenizar o dataset
    tokenized_test_data = TokenizeDataset(df_test, tokenizer, max_len)

    # Criar DataLoader para carregar os dados em lotes durante o treinamento
    test_loader = DataLoader(tokenized_test_data,
                              batch_size=test_batch_size, shuffle=True)

    model.eval()
    all_predictions = []
    sigmoid = torch.nn.Sigmoid()
    with torch.no_grad():
        for batch in test_loader:
            inputs_ids = batch['input_ids']
            attention_mask = batch['attention_mask']
            token_type_ids = batch['token_type_ids']

            # Passagem Direta (inferência)
            outputs = model(input_ids=inputs_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)

            # A função sigmóide é aplicada aos logits para converter os valores em probabilidades
            logits = outputs.logits
            predicted_probs = sigmoid(logits)

            # Aplicação do threshold
            predicted_labels = (predicted_probs > threshold).float()

            # Conversão dos rótulos previstos para numpy arrays
            predicted_labels_np = predicted_labels.cpu().numpy()

            # Coleção das predictions
            all_predictions.extend(predicted_labels_np)
    
    # Calcular o tempo total de teste
    end_time = time.time()
    elapsed_time = end_time - start_time
    hours, rem = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(rem, 60)

    print(
        f"\nTempo de predição: {int(hours):02}:{int(minutes):02}:{seconds:.2f}")

    return all_predictions

# %% [markdown]
# ## Aplicação do modelo

# %%
# Importar o modelo
model_dir = './bertimbau-model'
model = BertForSequenceClassification.from_pretrained(model_dir)

# %%
name = 'teste1'

# Fazer previsões no dataset sem anotações
predictions = run_prediction(model, df)

# Salvar as previsões em um arquivo CSV
predictions_df = pd.DataFrame(predictions, columns=labels)
predictions_df.to_csv(f'../datasets/dataset-case_study_predictions-{name}.csv', index=False)
# Out:
# c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 4
#       1 name = 'teste1'
#       3 # Fazer previsões no dataset sem anotações
# ----> 4 predictions = run_prediction(model, df)
#       6 # Salvar as previsões em um arquivo CSV
#       7 predictions_df = pd.DataFrame(predictions, columns=labels)
#
# Cell In[41], line 25, in run_prediction(model, df_test)
#      22 token_type_ids = batch['token_type_ids']
#      24 # Passagem Direta (inferência)
# ---> 25 outputs = model(input_ids=inputs_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
#      27 # A função sigmóide é aplicada aos logits para converter os valores em probabilidades
#      28 logits = outputs.logits
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:1539, in BertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1531 r"""
#    1532 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1533     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1534     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1535     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1536 """
#    1537 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1539 outputs = self.bert(
#    1540     input_ids,
#    1541     attention_mask=attention_mask,
#    1542     token_type_ids=token_type_ids,
#    1543     position_ids=position_ids,
#    1544     head_mask=head_mask,
#    1545     inputs_embeds=inputs_embeds,
#    1546     output_attentions=output_attentions,
#    1547     output_hidden_states=output_hidden_states,
#    1548     return_dict=return_dict,
#    1549 )
#    1551 pooled_output = outputs[1]
#    1553 pooled_output = self.dropout(pooled_output)
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:988, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     979 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     981 embedding_output = self.embeddings(
#     982     input_ids=input_ids,
#     983     position_ids=position_ids,
#    (...)
#     986     past_key_values_length=past_key_values_length,
#     987 )
# --> 988 encoder_outputs = self.encoder(
#     989     embedding_output,
#     990     attention_mask=extended_attention_mask,
#     991     head_mask=head_mask,
#     992     encoder_hidden_states=encoder_hidden_states,
#     993     encoder_attention_mask=encoder_extended_attention_mask,
#     994     past_key_values=past_key_values,
#     995     use_cache=use_cache,
#     996     output_attentions=output_attentions,
#     997     output_hidden_states=output_hidden_states,
#     998     return_dict=return_dict,
#     999 )
#    1000 sequence_output = encoder_outputs[0]
#    1001 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:582, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     571     layer_outputs = self._gradient_checkpointing_func(
#     572         layer_module.__call__,
#     573         hidden_states,
#    (...)
#     579         output_attentions,
#     580     )
#     581 else:
# --> 582     layer_outputs = layer_module(
#     583         hidden_states,
#     584         attention_mask,
#     585         layer_head_mask,
#     586         encoder_hidden_states,
#     587         encoder_attention_mask,
#     588         past_key_value,
#     589         output_attentions,
#     590     )
#     592 hidden_states = layer_outputs[0]
#     593 if use_cache:
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:472, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     460 def forward(
#     461     self,
#     462     hidden_states: torch.Tensor,
#    (...)
#     469 ) -> Tuple[torch.Tensor]:
#     470     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     471     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 472     self_attention_outputs = self.attention(
#     473         hidden_states,
#     474         attention_mask,
#     475         head_mask,
#     476         output_attentions=output_attentions,
#     477         past_key_value=self_attn_past_key_value,
#     478     )
#     479     attention_output = self_attention_outputs[0]
#     481     # if decoder, the last output is tuple of self-attn cache
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:402, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     392 def forward(
#     393     self,
#     394     hidden_states: torch.Tensor,
#    (...)
#     400     output_attentions: Optional[bool] = False,
#     401 ) -> Tuple[torch.Tensor]:
# --> 402     self_outputs = self.self(
#     403         hidden_states,
#     404         attention_mask,
#     405         head_mask,
#     406         encoder_hidden_states,
#     407         encoder_attention_mask,
#     408         past_key_value,
#     409         output_attentions,
#     410     )
#     411     attention_output = self.output(self_outputs[0], hidden_states)
#     412     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:330, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     327     attention_scores = attention_scores + attention_mask
#     329 # Normalize the attention scores to probabilities.
# --> 330 attention_probs = nn.functional.softmax(attention_scores, dim=-1)
#     332 # This is actually dropping out entire tokens to attend to, which might
#     333 # seem a bit unusual, but is taken from the original Transformer paper.
#     334 attention_probs = self.dropout(attention_probs)
#
# File c:\VSCODEProjects\artigo2024\venv\Lib\site-packages\torch\nn\functional.py:1885, in softmax(input, dim, _stacklevel, dtype)
#    1883     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1884 if dtype is None:
# -> 1885     ret = input.softmax(dim)
#    1886 else:
#    1887     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:
